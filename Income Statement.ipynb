# %%
import PyPDF2

# %%
f = open('Income Statement.pdf','rb')

# %%
pdf_reader = PyPDF2.PdfReader(f)

# %%
len(pdf_reader.pages)
# Out:
# 2

# %%
page_one = pdf_reader.pages[0]

# %%
print(page_one.extract_text())
# Out:
# Income Statement
# Revenue 2465845 3337103 6409395 12065186 15953224
# Total Revenue 2465845 3337103 6409395 12065186 15953224
# COGS 1094598 1682301 3378814 6567888 9068961
# Gross Profit 1371247 1654802 3030581 5497298 6884263
# Operating Expense 900808 1066222 1613774 2999898 3924853
# Operating Income 470439 588580 1416807 2497400 2959410
# Interest Expense 483 494 518 502 506
# Income Before Tax 469956 588086 1416289 2496898 2958904
# Taxes 106863 227373 516653 704631 809366
# Income After Tax 363093 360713 899636 1792267 2149538
# Total Extraordinary Items 0 0 0 0 0
# Net Income 363093 360713 899636 1792267 2149538

# %%
f.close()
